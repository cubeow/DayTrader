# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/Users/sagewong/git/DayTrader/IntradayStockData/AAPL_1min_firstratedata.csv")

plt.plot(df['timestamp'][:1000], df['open'][:1000])
plt.show()
